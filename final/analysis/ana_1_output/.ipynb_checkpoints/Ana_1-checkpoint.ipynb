# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import os
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from datetime import datetime

# %%
# Read downloaded data
p = Path(os.getcwd())
path = str(p.parent.parent) + '/data/AAPL/AAPL.csv'
df = pd.read_csv(path)
df.tail()
# Out:
#             Date   Open   High    Low  Close     Volume  Dividend  Split  \
# 9164  1980-12-18  26.63  26.75  26.63  26.63   327900.0       0.0    1.0
# 9165  1980-12-17  25.87  26.00  25.87  25.87   385900.0       0.0    1.0
# 9166  1980-12-16  25.37  25.37  25.25  25.25   472000.0       0.0    1.0
# 9167  1980-12-15  27.38  27.38  27.25  27.25   785200.0       0.0    1.0
# 9168  1980-12-12  28.75  28.87  28.75  28.75  2093900.0       0.0    1.0
#
#       Adj_Open  Adj_High   Adj_Low  Adj_Close   Adj_Volume
# 9164  0.394733  0.396512  0.394733   0.394733   18362400.0
# 9165  0.383468  0.385395  0.383468   0.383468   21610400.0
# 9166  0.376057  0.376057  0.374278   0.374278   26432000.0
# 9167  0.405851  0.405851  0.403924   0.403924   43971200.0
# 9168  0.426158  0.427937  0.426158   0.426158  117258400.0

# %%
df = df[df.apply(lambda x: int(x['Date'].split('-')[0]) >= 2016, axis=1)]
df['Date'] = df['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())
df.head()
# Out:
#          Date    Open    High     Low   Close      Volume  Dividend  Split  \
# 0  2017-04-21  142.44  142.68  141.85  142.27  17320928.0       0.0    1.0
# 1  2017-04-20  141.22  142.92  141.16  142.44  23319562.0       0.0    1.0
# 2  2017-04-19  141.88  142.00  140.45  140.68  17328375.0       0.0    1.0
# 3  2017-04-18  141.41  142.04  141.11  141.20  14697544.0       0.0    1.0
# 4  2017-04-17  141.48  141.88  140.87  141.83  16582094.0       0.0    1.0
#
#    Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# 0    142.44    142.68   141.85     142.27  17320928.0
# 1    141.22    142.92   141.16     142.44  23319562.0
# 2    141.88    142.00   140.45     140.68  17328375.0
# 3    141.41    142.04   141.11     141.20  14697544.0
# 4    141.48    141.88   140.87     141.83  16582094.0

# %%
df.describe()
# Out:
#             Open        High         Low       Close        Volume  \
# count  329.00000  329.000000  329.000000  329.000000  3.290000e+02
# mean   111.29386  112.186469  110.550467  111.437675  3.546626e+07
# std     14.70205   14.635344   14.824287   14.763443  1.698838e+07
# min     90.00000   91.670000   89.470000   90.340000  0.000000e+00
# 25%     98.70000   99.870000   98.110000   98.830000  2.513956e+07
# 50%    108.77000  109.690000  108.110000  108.850000  3.083700e+07
# 75%    116.86000  117.760000  116.470000  117.060000  4.035138e+07
# max    144.29000  145.460000  143.810000  144.770000  1.333697e+08
#
#          Dividend  Split    Adj_Open    Adj_High     Adj_Low   Adj_Close  \
# count  329.000000  329.0  329.000000  329.000000  329.000000  329.000000
# mean     0.008511    1.0  110.139895  111.021832  109.406333  110.282824
# std      0.068658    0.0   15.329024   15.267247   15.448658   15.392214
# min      0.000000    1.0   88.674156   90.319554   88.151964   89.009147
# 25%      0.000000    1.0   97.216433   98.075940   96.112933   97.324813
# 50%      0.000000    1.0  107.446799  108.210639  106.744152  107.534935
# 75%      0.000000    1.0  116.223936  116.876905  115.701963  116.259562
# max      0.570000    1.0  144.290000  145.460000  143.810000  144.770000
#
#          Adj_Volume
# count  3.290000e+02
# mean   3.546626e+07
# std    1.698838e+07
# min    0.000000e+00
# 25%    2.513956e+07
# 50%    3.083700e+07
# 75%    4.035138e+07
# max    1.333697e+08

# %%
months = dates.MonthLocator()
yearsFmt = dates.DateFormatter('%Y%b')

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(yearsFmt)

ax.plot(df['Date'], df['Adj_Close'])

datemin = datetime(2016, 1, 1)
datemax = datetime(2017, 2, 1)
ax.set_xlim(datemin, datemax)
ax.format_xdata = mdate.DateFormatter('%Y-%M-%d')
fig.autofmt_xdate()
fig.set_size_inches(10,4)
ax.legend()
ax.set_ylim(80,140)
plt.savefig('ana_1_output/Adj_Close.png')
# Out:
# (80, 140)

# %%
months = dates.MonthLocator()
yearsFmt = dates.DateFormatter('%Y%b')

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(yearsFmt)

ax.plot(df['Date'], df['Volume'])

datemin = datetime(2016, 1, 1)
datemax = datetime(2017, 2, 1)
ax.set_xlim(datemin, datemax)
ax.format_xdata = mdate.DateFormatter('%Y-%M-%d')
fig.autofmt_xdate()
fig.set_size_inches(10,4)
ax.legend()

# %%
df['Volume'].plot(legend=True,figsize=(10,4))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-b0360672eb98> in <module>()
# ----> 1 volume_df = df[df['Date'] >= datetime.date( 2016, 1, 1 )]
#       2 fig, ax = plt.subplots()
#       3 ax = volume_df['Volume'].plot(kind='Bar', color=['r' if x[5] > x[2] else 'g' for x in volume_df.itertuples()])
#       4 ax.set_xticklabels([x.strftime('%Y-%m-%d') for x in volume_df['Date']])
#       5 fig.show()
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'int'
